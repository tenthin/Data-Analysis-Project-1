# %%
import pandas as pd

# %%
df=pd.read_csv("transformed_datap.csv")

# %%
df.head(5)
# Out:
#   CODE      COUNTRY      DATE  human_development_index  Total_Cases  \
# 0  AFG  Afghanistan  31-12-19                    0.498          0.0
# 1  AFG  Afghanistan  01-01-20                    0.498          0.0
# 2  AFG  Afghanistan  02-01-20                    0.498          0.0
# 3  AFG  Afghanistan  03-01-20                    0.498          0.0
# 4  AFG  Afghanistan  04-01-20                    0.498          0.0
#
#    Total_Deaths  Stringency_Index  Population  gdp_per_capita
# 0           0.0               0.0   17.477233        7.497754
# 1           0.0               0.0   17.477233        7.497754
# 2           0.0               0.0   17.477233        7.497754
# 3           0.0               0.0   17.477233        7.497754
# 4           0.0               0.0   17.477233        7.497754

# %%
g=df.groupby('COUNTRY')

# %% [markdown]
# # SPLIT, APPLY, COMBINE

# %%
for COUNTRY,COUNTRY_df in g:
    print(COUNTRY)
    print(COUNTRY_df)
# Out:
# Afghanistan
#     CODE      COUNTRY      DATE  human_development_index  Total_Cases  \
# 0    AFG  Afghanistan  31-12-19                    0.498     0.000000
# 1    AFG  Afghanistan  01-01-20                    0.498     0.000000
# 2    AFG  Afghanistan  02-01-20                    0.498     0.000000
# 3    AFG  Afghanistan  03-01-20                    0.498     0.000000
# 4    AFG  Afghanistan  04-01-20                    0.498     0.000000
# ..   ...          ...       ...                      ...          ...
# 289  AFG  Afghanistan  15-10-20                    0.498    10.597285
# 290  AFG  Afghanistan  16-10-20                    0.498    10.597285
# 291  AFG  Afghanistan  17-10-20                    0.498    10.598458
# 292  AFG  Afghanistan  18-10-20                    0.498    10.600154
# 293  AFG  Afghanistan  19-10-20                    0.498    10.601622
#
#      Total_Deaths  Stringency_Index  Population  gdp_per_capita
# ...

# %%
g.get_group('Afghanistan')
# Out:
#     CODE      COUNTRY      DATE  human_development_index  Total_Cases  \
# 0    AFG  Afghanistan  31-12-19                    0.498     0.000000
# 1    AFG  Afghanistan  01-01-20                    0.498     0.000000
# 2    AFG  Afghanistan  02-01-20                    0.498     0.000000
# 3    AFG  Afghanistan  03-01-20                    0.498     0.000000
# 4    AFG  Afghanistan  04-01-20                    0.498     0.000000
# ..   ...          ...       ...                      ...          ...
# 289  AFG  Afghanistan  15-10-20                    0.498    10.597285
# 290  AFG  Afghanistan  16-10-20                    0.498    10.597285
# 291  AFG  Afghanistan  17-10-20                    0.498    10.598458
# 292  AFG  Afghanistan  18-10-20                    0.498    10.600154
# 293  AFG  Afghanistan  19-10-20                    0.498    10.601622
#
#      Total_Deaths  Stringency_Index  Population  gdp_per_capita
# ...

# %%
g.max()
# Out:
#             CODE      DATE  human_development_index  Total_Cases  \
# COUNTRY
# Afghanistan  AFG  31-12-19                    0.498    10.601622
# Albania      ALB  31-08-20                    0.785     9.744199
# Algeria      DZA  31-12-19                    0.754    10.904156
# Andorra      AND  31-08-20                    0.858     8.124743
# Angola       AGO  31-08-20                    0.581     8.917579
# ...          ...       ...                      ...          ...
# Venezuela    VEN  31-08-20                    0.761    11.369471
# Vietnam      VNM  31-12-19                    0.694     7.033506
# Yemen        YEM  31-08-20                    0.452     7.629976
# Zambia       ZMB  31-08-20                    0.588     9.671114
# Zimbabwe     ZWE  31-08-20                    0.535     9.005405
#
#              Total_Deaths  Stringency_Index  Population  gdp_per_capita
# COUNTRY
# Afghanistan      7.307873          4.433907   17.477233        7.497754
# ...

# %%
g.min()
# Out:
#             CODE      DATE  human_development_index  Total_Cases  \
# COUNTRY
# Afghanistan  AFG  01-01-20                    0.498     0.000000
# Albania      ALB  01-04-20                    0.785     0.693147
# Algeria      DZA  01-01-20                    0.754     0.000000
# Andorra      AND  01-04-20                    0.858     0.000000
# Angola       AGO  01-04-20                    0.581     0.693147
# ...          ...       ...                      ...          ...
# Venezuela    VEN  01-04-20                    0.761     0.000000
# Vietnam      VNM  01-01-20                    0.694     0.000000
# Yemen        YEM  01-05-20                    0.452     0.000000
# Zambia       ZMB  01-04-20                    0.588     0.693147
# Zimbabwe     ZWE  01-04-20                    0.535     0.000000
#
#              Total_Deaths  Stringency_Index  Population  gdp_per_capita
# COUNTRY
# Afghanistan           0.0          0.000000   17.477233        7.497754
# ...

# %%
g.mean()
# Out:
#              human_development_index  Total_Cases  Total_Deaths  \
# COUNTRY
# Afghanistan                    0.498     6.804919      4.173293
# Albania                        0.785     7.565514      4.130528
# Algeria                        0.754     6.981329      4.783049
# Andorra                        0.858     6.485966      3.480775
# Angola                         0.581     5.679145      2.783673
# ...                              ...          ...           ...
# Venezuela                      0.761     8.268582      3.895227
# Vietnam                        0.694     4.933531      0.889582
# Yemen                          0.452     6.027499      4.808522
# Zambia                         0.588     7.165626      3.383976
# Zimbabwe                       0.535     6.196063      2.902239
#
#              Stringency_Index  Population  gdp_per_capita
# COUNTRY
# Afghanistan          3.049673   17.477233        7.497754
# Albania              3.927348   14.872537        9.376146
# ...

# %%
g.describe()
# Out:
#             human_development_index                                            \
#                               count   mean           std    min    25%    50%
# COUNTRY
# Afghanistan                   294.0  0.498  3.892406e-16  0.498  0.498  0.498
# Albania                       225.0  0.785  2.781746e-15  0.785  0.785  0.785
# Algeria                       294.0  0.754  2.780290e-15  0.754  0.754  0.754
# Andorra                       226.0  0.858  2.336644e-15  0.858  0.858  0.858
# Angola                        212.0  0.581  2.225702e-15  0.581  0.581  0.581
# ...                             ...    ...           ...    ...    ...    ...
# Venezuela                     219.0  0.761  2.114256e-15  0.761  0.761  0.761
# Vietnam                       294.0  0.694  3.225136e-15  0.694  0.694  0.694
# Yemen                         193.0  0.452  7.791773e-16  0.452  0.452  0.452
# Zambia                        215.0  0.588  2.782035e-15  0.588  0.588  0.588
# ...

# %%
df.shape
# Out:
# (50418, 9)

# %% [markdown]
# # slicing

# %%
df[2:5]
# Out:
#   CODE      COUNTRY      DATE  human_development_index  Total_Cases  \
# 2  AFG  Afghanistan  02-01-20                    0.498          0.0
# 3  AFG  Afghanistan  03-01-20                    0.498          0.0
# 4  AFG  Afghanistan  04-01-20                    0.498          0.0
#
#    Total_Deaths  Stringency_Index  Population  gdp_per_capita
# 2           0.0               0.0   17.477233        7.497754
# 3           0.0               0.0   17.477233        7.497754
# 4           0.0               0.0   17.477233        7.497754

# %%
df[:]
# Out:
#       CODE      COUNTRY      DATE  human_development_index  Total_Cases  \
# 0      AFG  Afghanistan  31-12-19                    0.498     0.000000
# 1      AFG  Afghanistan  01-01-20                    0.498     0.000000
# 2      AFG  Afghanistan  02-01-20                    0.498     0.000000
# 3      AFG  Afghanistan  03-01-20                    0.498     0.000000
# 4      AFG  Afghanistan  04-01-20                    0.498     0.000000
# ...    ...          ...       ...                      ...          ...
# 50413  ZWE     Zimbabwe  15-10-20                    0.535     8.994048
# 50414  ZWE     Zimbabwe  16-10-20                    0.535     8.996528
# 50415  ZWE     Zimbabwe  17-10-20                    0.535     8.999496
# 50416  ZWE     Zimbabwe  18-10-20                    0.535     9.000853
# 50417  ZWE     Zimbabwe  19-10-20                    0.535     9.005405
#
#        Total_Deaths  Stringency_Index  Population  gdp_per_capita
# ...

# %%
df.columns
# Out:
# Index(['CODE', 'COUNTRY', 'DATE', 'human_development_index', 'Total_Cases',
#        'Total_Deaths', 'Stringency_Index', 'Population', 'gdp_per_capita'],
#       dtype='object')

# %% [markdown]
# # to print individual column

# %%
df.CODE
# Out:
# 0        AFG
# 1        AFG
# 2        AFG
# 3        AFG
# 4        AFG
#         ...
# 50413    ZWE
# 50414    ZWE
# 50415    ZWE
# 50416    ZWE
# 50417    ZWE
# Name: CODE, Length: 50418, dtype: object

# %% [markdown]
# # To print few selected columns

# %%
df[['CODE','COUNTRY']]
# Out:
#       CODE      COUNTRY
# 0      AFG  Afghanistan
# 1      AFG  Afghanistan
# 2      AFG  Afghanistan
# 3      AFG  Afghanistan
# 4      AFG  Afghanistan
# ...    ...          ...
# 50413  ZWE     Zimbabwe
# 50414  ZWE     Zimbabwe
# 50415  ZWE     Zimbabwe
# 50416  ZWE     Zimbabwe
# 50417  ZWE     Zimbabwe
#
# [50418 rows x 2 columns]

# %%
df.Total_Deaths.max()
# Out:
# 12.29989991

# %% [markdown]
# # no. of deaths greater than 12

# %%
df[df.Total_Deaths>12]
# Out:
#       CODE        COUNTRY      DATE  human_development_index  Total_Cases  \
# 48344  USA  United States  10-08-20                    0.924    15.433881
# 48345  USA  United States  11-08-20                    0.924    15.443651
# 48346  USA  United States  12-08-20                    0.924    15.452798
# 48347  USA  United States  13-08-20                    0.924    15.463621
# 48348  USA  United States  14-08-20                    0.924    15.473404
# ...    ...            ...       ...                      ...          ...
# 48410  USA  United States  15-10-20                    0.924    15.884409
# 48411  USA  United States  16-10-20                    0.924    15.892435
# 48412  USA  United States  17-10-20                    0.924    15.901200
# 48413  USA  United States  18-10-20                    0.924    15.908208
# 48414  USA  United States  19-10-20                    0.924    15.914092
#
#        Total_Deaths  Stringency_Index  Population  gdp_per_capita
# ...

# %% [markdown]
# # to print a row in a dataframe

# %%
df[df.Total_Cases == df.Total_Cases.max()]
# Out:
#       CODE        COUNTRY      DATE  human_development_index  Total_Cases  \
# 48414  USA  United States  19-10-20                    0.924    15.914092
#
#        Total_Deaths  Stringency_Index  Population  gdp_per_capita
# 48414       12.2999               0.0   19.617637       10.900906

# %% [markdown]
# # to print only the country when the total case was max

# %%
df['COUNTRY'][df.Total_Cases == df.Total_Cases.max()]
# Out:
# 48414    United States
# Name: COUNTRY, dtype: object

# %% [markdown]
# # to print country and date for when total case was max

# %%
df[['COUNTRY','DATE']][df.Total_Cases == df.Total_Cases.max()]
# Out:
#              COUNTRY      DATE
# 48414  United States  19-10-20

# %%
df.head()
# Out:
#   CODE      COUNTRY      DATE  human_development_index  Total_Cases  \
# 0  AFG  Afghanistan  31-12-19                    0.498          0.0
# 1  AFG  Afghanistan  01-01-20                    0.498          0.0
# 2  AFG  Afghanistan  02-01-20                    0.498          0.0
# 3  AFG  Afghanistan  03-01-20                    0.498          0.0
# 4  AFG  Afghanistan  04-01-20                    0.498          0.0
#
#    Total_Deaths  Stringency_Index  Population  gdp_per_capita
# 0           0.0               0.0   17.477233        7.497754
# 1           0.0               0.0   17.477233        7.497754
# 2           0.0               0.0   17.477233        7.497754
# 3           0.0               0.0   17.477233        7.497754
# 4           0.0               0.0   17.477233        7.497754

# %%
df
# Out:
#        level_0      DATE  index CODE      COUNTRY  human_development_index  \
# 0            0  31-12-19      0  AFG  Afghanistan                    0.498
# 1            1  01-01-20      1  AFG  Afghanistan                    0.498
# 2            2  02-01-20      2  AFG  Afghanistan                    0.498
# 3            3  03-01-20      3  AFG  Afghanistan                    0.498
# 4            4  04-01-20      4  AFG  Afghanistan                    0.498
# ...        ...       ...    ...  ...          ...                      ...
# 50413    50413  15-10-20  50413  ZWE     Zimbabwe                    0.535
# 50414    50414  16-10-20  50414  ZWE     Zimbabwe                    0.535
# 50415    50415  17-10-20  50415  ZWE     Zimbabwe                    0.535
# 50416    50416  18-10-20  50416  ZWE     Zimbabwe                    0.535
# 50417    50417  19-10-20  50417  ZWE     Zimbabwe                    0.535
#
# ...

# %%
del df['index']

# %%
df
# Out:
#            DATE CODE      COUNTRY  human_development_index  Total_Cases  \
# 0      31-12-19  AFG  Afghanistan                    0.498     0.000000
# 1      01-01-20  AFG  Afghanistan                    0.498     0.000000
# 2      02-01-20  AFG  Afghanistan                    0.498     0.000000
# 3      03-01-20  AFG  Afghanistan                    0.498     0.000000
# 4      04-01-20  AFG  Afghanistan                    0.498     0.000000
# ...         ...  ...          ...                      ...          ...
# 50413  15-10-20  ZWE     Zimbabwe                    0.535     8.994048
# 50414  16-10-20  ZWE     Zimbabwe                    0.535     8.996528
# 50415  17-10-20  ZWE     Zimbabwe                    0.535     8.999496
# 50416  18-10-20  ZWE     Zimbabwe                    0.535     9.000853
# 50417  19-10-20  ZWE     Zimbabwe                    0.535     9.005405
#
#        Total_Deaths  Stringency_Index  Population  gdp_per_capita
# ...

# %%
df.loc[[1,2]]
# Out:
#        DATE CODE      COUNTRY  human_development_index  Total_Cases  \
# 1  01-01-20  AFG  Afghanistan                    0.498          0.0
# 2  02-01-20  AFG  Afghanistan                    0.498          0.0
#
#    Total_Deaths  Stringency_Index  Population  gdp_per_capita
# 1           0.0               0.0   17.477233        7.497754
# 2           0.0               0.0   17.477233        7.497754

# %%
df.isnull().count()
# Out:
# DATE                       50418
# CODE                       50418
# COUNTRY                    50418
# human_development_index    50418
# Total_Cases                50418
# Total_Deaths               50418
# Stringency_Index           50418
# Population                 50418
# gdp_per_capita             50418
# dtype: int64
